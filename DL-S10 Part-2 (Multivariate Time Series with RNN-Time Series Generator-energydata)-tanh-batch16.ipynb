# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Session - 10 Part - 2<br><br>Multivariate Time Series Forecasting with RNN<br><br>(Time Series Generator)<br><h1>

# %% [markdown]
# # Dataset Info

# %% [markdown]
# Appliance Energy Usage: A Multivariate Time Series Forecasting Example
#
# Experimental data used to create regression models of appliances energy use in a low energy building.
# Data Set Information:
#
# The data set is at 10 min for about 4.5 months. The house temperature and humidity conditions were monitored with a ZigBee wireless sensor network. Each wireless node transmitted the temperature and humidity conditions around 3.3 min. Then, the wireless data was averaged for 10 minutes periods. The energy data was logged every 10 minutes with m-bus energy meters. Weather from the nearest airport weather station (Chievres Airport, Belgium) was downloaded from a public data set from Reliable Prognosis (rp5.ru), and merged together with the experimental data sets using the date and time column. Two random variables have been included in the data set for testing the regression models and to filter out non predictive attributes (parameters).
# Original source of the dataset:
#
# http://archive.ics.uci.edu/ml/datasets/Appliances+energy+prediction

# %% [markdown]
# - date time year-month-day hour:minute:second
# - Appliances, energy use in Wh
# - lights, energy use of light fixtures in the house in Wh
# - T1, Temperature in kitchen area, in Celsius
# - RH_1, Humidity in kitchen area, in %
# - T2, Temperature in living room area, in Celsius
# - RH_2, Humidity in living room area, in %
# - T3, Temperature in laundry room area
# - RH_3, Humidity in laundry room area, in %
# - T4, Temperature in office room, in Celsius
# - RH_4, Humidity in office room, in %
# - T5, Temperature in bathroom, in Celsius
# - RH_5, Humidity in bathroom, in %
# - T6, Temperature outside the building (north side), in Celsius
# - RH_6, Humidity outside the building (north side), in %
# - T7, Temperature in ironing room , in Celsius
# - RH_7, Humidity in ironing room, in %
# - T8, Temperature in teenager room 2, in Celsius
# - RH_8, Humidity in teenager room 2, in %
# - T9, Temperature in parents room, in Celsius
# - RH_9, Humidity in parents room, in %
# - To, Temperature outside (from Chievres weather station), in Celsius
# - Pressure (from Chievres weather station), in mm Hg
# - RH_out, Humidity outside (from Chievres weather station), in %
# - Wind speed (from Chievres weather station), in m/s
# - Visibility (from Chievres weather station), in km
# - Tdewpoint (from Chievres weather station), Â°C
# - rv1, Random variable 1, nondimensional
# - rv2, Random variable 2, nondimensional

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Recognizing and Understanding Data

# %%
df = pd.read_csv('../data/energydata_complete.csv',index_col='date', parse_dates = True)

# %%
df.head()
# Out:
#                      Appliances  lights     T1   RH_1     T2   RH_2     T3  \
# date
# 2016-01-11 17:00:00          60      30 19.890 47.597 19.200 44.790 19.790
# 2016-01-11 17:10:00          60      30 19.890 46.693 19.200 44.722 19.790
# 2016-01-11 17:20:00          50      30 19.890 46.300 19.200 44.627 19.790
# 2016-01-11 17:30:00          50      40 19.890 46.067 19.200 44.590 19.790
# 2016-01-11 17:40:00          60      40 19.890 46.333 19.200 44.530 19.790
#
#                       RH_3     T4   RH_4     T5   RH_5    T6   RH_6     T7  \
# date
# 2016-01-11 17:00:00 44.730 19.000 45.567 17.167 55.200 7.027 84.257 17.200
# 2016-01-11 17:10:00 44.790 19.000 45.992 17.167 55.200 6.833 84.063 17.200
# 2016-01-11 17:20:00 44.933 18.927 45.890 17.167 55.090 6.560 83.157 17.200
# 2016-01-11 17:30:00 45.000 18.890 45.723 17.167 55.090 6.433 83.423 17.133
# 2016-01-11 17:40:00 45.000 18.890 45.530 17.200 55.090 6.367 84.893 17.200
#
#                       RH_7     T8   RH_8     T9   RH_9  T_out  Press_mm_hg  \
# date
# 2016-01-11 17:00:00 41.627 18.200 48.900 17.033 45.530  6.600      733.500
# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ## Feature Engineering
# - Let's reduce the number of feature
# - Let's resample the dataset by hours

# %%
df.columns
# Out:
# Index(['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4',
#        'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9',
#        'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
#        'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
df=df.rename(columns = {'T6':'T_outside', 'RH_6':'RH_outside'})
df["T_inside"] = (df["T1"] + df["T2"] + df["T3"] + df["T4"] + df["T5"] + df["T7"] + df["T8"] + df["T9"])/8
df["RH_inside"] = (df["RH_1"] + df["RH_2"] + df["RH_3"] + df["RH_4"] + df["RH_5"] + df["RH_7"] + df["RH_8"] + df["RH_9"])/8

# %%
drop_list = ['T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4', 'T5', 'RH_5',
             'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'T_out', 'RH_out', 'rv1', 'rv2']
df.drop(drop_list, axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19735 entries, 2016-01-11 17:00:00 to 2016-05-27 18:00:00
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Appliances   19735 non-null  int64
#  1   lights       19735 non-null  int64
#  2   T_outside    19735 non-null  float64
#  3   RH_outside   19735 non-null  float64
#  4   Press_mm_hg  19735 non-null  float64
#  5   Windspeed    19735 non-null  float64
#  6   Visibility   19735 non-null  float64
#  7   Tdewpoint    19735 non-null  float64
#  8   T_inside     19735 non-null  float64
#  9   RH_inside    19735 non-null  float64
# dtypes: float64(8), int64(2)
# memory usage: 1.7 MB

# %%
df_a = df[["Appliances", "lights"]]
df_b = df.drop(["Appliances", "lights"], axis = 1)

# %%
df_a = df_a.resample("H").sum() # convert to hourly data, Index must be date data
df_b = df_b.resample("H").mean()

# %%
df = pd.concat([df_a, df_b], axis =1)
df.head()
# Out:
#                      Appliances  lights  T_outside  RH_outside  Press_mm_hg  \
# date
# 2016-01-11 17:00:00         330     210      6.587      84.260      733.750
# 2016-01-11 18:00:00        1060     310      6.180      87.204      734.267
# 2016-01-11 19:00:00        1040     150      5.857      88.131      734.792
# 2016-01-11 20:00:00         750     210      5.469      86.934      735.283
# 2016-01-11 21:00:00         620     140      5.579      86.129      735.567
#
#                      Windspeed  Visibility  Tdewpoint  T_inside  RH_inside
# date
# 2016-01-11 17:00:00      6.167      53.417      5.050    18.415     46.555
# 2016-01-11 18:00:00      5.417      40.000      4.658    18.408     46.520
# 2016-01-11 19:00:00      6.000      40.000      4.392    18.686     48.665
# 2016-01-11 20:00:00      6.000      40.000      4.017    18.941     50.356
# 2016-01-11 21:00:00      6.000      40.000      3.817    19.254     48.977

# %%
df.shape
# Out:
# (3290, 10)

# %% [markdown]
# Let's also round off the data, to one decimal point precision, otherwise this may cause issues with our network (we will also normalize the data anyways, so this level of precision isn't useful to us)

# %%
df = df.round(2)

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), annot=True);

# %%
df['Appliances'].plot(figsize=(18,6))
plt.xticks(rotation=90);

# %%
df['Appliances'].loc["2016-05-01 00:00:00" : "2016-05-07 23:00:00"].plot(figsize=(18,6))
plt.xticks(rotation=90);

# %% [markdown]
# ## Train Test Split

# %%
len(df)
# Out:
# 3290

# %%
# How many rows per day?
24
# Out:
# 24

# %%
test_days = 7

# %%
test_ind = test_days*24

# %%
test_ind
# Out:
# 168

# %%
train = df.iloc[:-test_ind]
test = df.iloc[-test_ind:]

# %%
train.shape, test.shape
# Out:
# ((3122, 10), (168, 10))

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler

# %%
scaler = MinMaxScaler()

# %%
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# %% [markdown]
# # Modelling

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
length = 24 # Length of the output sequences (in number of timesteps)
batch_size = 1 #Number of timeseries samples in each batch
generator = TimeseriesGenerator(train_scaled, train_scaled, length=length, batch_size=batch_size)
validation_generator = TimeseriesGenerator(test_scaled, test_scaled, length=length, batch_size=batch_size)

# %%
len(train_scaled), len(generator), len(test_scaled), len(validation_generator)
# Out:
# (3122, 3098, 168, 144)

# %%
n_features = train_scaled.shape[1]

# %%
model = Sequential()

model.add(LSTM(100,input_shape=(length, n_features)))

model.add(Dense(n_features))

model.compile(optimizer='adam', loss='mse')
# Out:
# 2022-06-19 23:04:04.731877: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=3, restore_best_weights = True)

# %%
model.fit(x = generator,
          epochs=20,
          validation_data=validation_generator,
          callbacks=[early_stop])
# Out:
# Epoch 1/20
# 3266/3266 [==============================] - 254s 71ms/step - loss: 0.0089 - val_loss: 0.0051
# Epoch 2/20
# 3266/3266 [==============================] - 245s 75ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 3/20
# 3266/3266 [==============================] - 212s 65ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 4/20
# 3266/3266 [==============================] - 204s 62ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 5/20
# 3266/3266 [==============================] - 234s 72ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 6/20
# 3266/3266 [==============================] - 184s 56ms/step - loss: 0.0040 - val_loss: 0.0041
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/ML/Documents/ABD2021/Course/Lectures/DL/In-class notebooks/DL-S10 Part-2 (Multivariate Time Series with RNN-Time Series Generator-energydata)-tanh-batch16.ipynb Cell 47' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ML/Documents/ABD2021/Course/Lectures/DL/In-class%20notebooks/DL-S10%20Part-2%20%28Multivariate%20Time%20Series%20with%20RNN-Time%20Series%20Generator-energydata%29-tanh-batch16.ipynb#ch0000046?line=0'>1</a> model.fit(x = generator,
#       <a href='vscode-notebook-cell:/Users/ML/Documents/ABD2021/Course/Lectures/DL/In-class%20notebooks/DL-S10%20Part-2%20%28Multivariate%20Time%20Series%20with%20RNN-Time%20Series%20Generator-energydata%29-tanh-batch16.ipynb#ch0000046?line=1'>2</a>           epochs=20,
#       <a href='vscode-notebook-cell:/Users/ML/Documents/ABD2021/Course/Lectures/DL/In-class%20notebooks/DL-S10%20Part-2%20%28Multivariate%20Time%20Series%20with%20RNN-Time%20Series%20Generator-energydata%29-tanh-batch16.ipynb#ch0000046?line=2'>3</a>           validation_data=validation_generator,
#       <a href='vscode-notebook-cell:/Users/ML/Documents/ABD2021/Course/Lectures/DL/In-class%20notebooks/DL-S10%20Part-2%20%28Multivariate%20Time%20Series%20with%20RNN-Time%20Series%20Generator-energydata%29-tanh-batch16.ipynb#ch0000046?line=3'>4</a>           callbacks=[early_stop])
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/engine/training.py:1373, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/engine/training.py?line=1370'>1371</a> logs = None
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/engine/training.py?line=1371'>1372</a> for epoch, iterator in data_handler.enumerate_epochs():
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/engine/training.py?line=1372'>1373</a>   self.reset_metrics()
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/engine/training.py?line=1373'>1374</a>   callbacks.on_epoch_begin(epoch)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/engine/training.py?line=1374'>1375</a>   with data_handler.catch_stop_iteration():
#
# KeyboardInterrupt:

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Evaluation on Test Data

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    score = r2_score(actual, pred)
    return print("r2_score:", score, "\nmae:", mae, "\nmse:",mse, "\nrmse:",rmse)

# %%
train_scaled
# Out:
# array([[0.04597701, 0.67741935, 0.36747872, ..., 0.53060285, 0.24072217,
#         0.72111369],
#        [0.25574713, 1.        , 0.35544467, ..., 0.51265532, 0.23971916,
#         0.71972158],
#        [0.25      , 0.48387097, 0.34605225, ..., 0.5002301 , 0.26780341,
#         0.81948956],
#        ...,
#        [0.03448276, 0.        , 0.79189903, ..., 0.86746434, 0.72016048,
#         0.65614849],
#        [0.08045977, 0.        , 0.78544174, ..., 0.81316153, 0.73420261,
#         0.69605568],
#        [0.0862069 , 0.03225806, 0.76342824, ..., 0.75977911, 0.75025075,
#         0.80510441]])

# %%
predictions_scaled = []

first_eval_batch = train_scaled[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(length):
    
    # get prediction 1 time stamp ahead
    current_pred = model.predict(current_batch)
    
    # store prediction
    predictions_scaled.append(current_pred[0]) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:, 1:, :], [current_pred], axis=1)

# %%
predictions_scaled
# Out:
# [array([0.03272367, 0.01362144, 0.72493464, 0.06412733, 0.65274894,
#         0.33573696, 0.5856743 , 0.75643635, 0.746358  , 0.7574221 ],
#        dtype=float32),
#  array([ 0.01460046, -0.01117106,  0.6920741 ,  0.15673786,  0.63940334,
#          0.33354676,  0.56241333,  0.76811624,  0.7360955 ,  0.6980221 ],
#        dtype=float32),
#  array([ 0.00408946, -0.02688114,  0.67048687,  0.23435076,  0.6231762 ,
#          0.33666068,  0.55579686,  0.7789364 ,  0.7243088 ,  0.6752743 ],
#        dtype=float32),
#  array([-0.00223711, -0.03621106,  0.6558006 ,  0.29482993,  0.6084298 ,
#          0.34113958,  0.5530547 ,  0.7894564 ,  0.7148181 ,  0.666504  ],
#        dtype=float32),
#  array([-0.00645179, -0.044443  ,  0.64735174,  0.33797514,  0.59494567,
#          0.34570047,  0.55187654,  0.79749507,  0.7082952 ,  0.6620874 ],
#        dtype=float32),
#  array([-0.00889082, -0.05398768,  0.6449356 ,  0.36465746,  0.58189106,
#          0.3500963 ,  0.55212194,  0.8020109 ,  0.70495176,  0.6577043 ],
#        dtype=float32),
#  array([-0.00887489, -0.06467322,  0.6480917 ,  0.37653562,  0.56861365,
#          0.3538061 ,  0.5539981 ,  0.80309016,  0.70479405,  0.6518555 ],
#        dtype=float32),
#  array([-0.00581089, -0.07506447,  0.65598863,  0.37580097,  0.5547056 ,
#          0.35628268,  0.5573346 ,  0.8012757 ,  0.7076065 ,  0.6443343 ],
#        dtype=float32),
#  array([ 5.4417551e-04, -8.3627120e-02,  6.6760337e-01,  3.6490083e-01,
#          5.3997517e-01,  3.5702422e-01,  5.6165206e-01,  7.9721403e-01,
#          7.1302462e-01,  6.3532257e-01], dtype=float32),
#  array([ 0.01004828, -0.08925615,  0.6818792 ,  0.34634787,  0.524387  ,
#          0.35589847,  0.5663018 ,  0.7915287 ,  0.72058713,  0.62501186],
#        dtype=float32),
#  array([ 0.02246754, -0.09135059,  0.6978722 ,  0.32259798,  0.50807613,
#          0.3530655 ,  0.5707388 ,  0.7848983 ,  0.7298167 ,  0.61354476],
#        dtype=float32),
#  array([ 0.03708603, -0.08988319,  0.7146667 ,  0.29596806,  0.491307  ,
#          0.34893504,  0.57458353,  0.7780967 ,  0.7402855 ,  0.6011574 ],
#        dtype=float32),
#  array([ 0.05301769, -0.0852145 ,  0.731342  ,  0.2686805 ,  0.47451133,
#          0.3439353 ,  0.5776415 ,  0.7720177 ,  0.7516066 ,  0.5882715 ],
#        dtype=float32),
#  array([ 0.0692711 , -0.07790518,  0.74696404,  0.24274322,  0.45823407,
#          0.33839127,  0.57989234,  0.7675667 ,  0.7634216 ,  0.57548386],
#        dtype=float32),
#  array([ 0.0847281 , -0.06863189,  0.7605809 ,  0.21981919,  0.44305772,
#          0.3324946 ,  0.58141786,  0.7655229 ,  0.77538437,  0.563541  ],
#        dtype=float32),
#  array([ 0.09843179, -0.05802395,  0.7713126 ,  0.20117088,  0.42952654,
#          0.32621774,  0.58234805,  0.7664577 ,  0.78713113,  0.55323416],
#        dtype=float32),
#  array([ 0.1094415 , -0.04670273,  0.7784334 ,  0.18758114,  0.41803935,
#          0.31946027,  0.58280605,  0.7706226 ,  0.7983082 ,  0.5452895 ],
#        dtype=float32),
#  array([ 0.11676209, -0.03533469,  0.78140396,  0.17942351,  0.40879276,
#          0.3121557 ,  0.58284616,  0.777963  ,  0.8085843 ,  0.5403044 ],
#        dtype=float32),
#  array([ 0.12028648, -0.02453306,  0.78022003,  0.17670909,  0.4017257 ,
#          0.30428818,  0.5825253 ,  0.78800195,  0.8176691 ,  0.5384676 ],
#        dtype=float32),
#  array([ 0.12047243, -0.0147613 ,  0.7754131 ,  0.1789345 ,  0.39654136,
#          0.29611266,  0.5819808 ,  0.7998638 ,  0.82538533,  0.5395711 ],
#        dtype=float32),
#  array([ 0.11698209, -0.00660767,  0.76756454,  0.18543753,  0.39277983,
#          0.2879817 ,  0.5812509 ,  0.8127015 ,  0.8316893 ,  0.5433536 ],
#        dtype=float32),
#  array([ 1.1018841e-01, -6.1106886e-04,  7.5739563e-01,  1.9563037e-01,
#          3.8989067e-01,  2.8021666e-01,  5.8032382e-01,  8.2563680e-01,
#          8.3656013e-01,  5.4931247e-01], dtype=float32),
#  array([0.10072287, 0.00278245, 0.7457303 , 0.20876352, 0.38724682,
#         0.27310476, 0.5792283 , 0.8378226 , 0.8400488 , 0.55680496],
#        dtype=float32),
#  array([0.08958665, 0.00345709, 0.73339677, 0.22400299, 0.38427478,
#         0.2668026 , 0.5780784 , 0.84859604, 0.84226435, 0.56518775],
#        dtype=float32)]

# %%
eval_metrics(test_scaled[:length], predictions_scaled)
# Out:
# r2_score: -4.207526793838625
# mae: 0.10193861138812015
# mse: 0.01859998612770574
# rmse: 0.13638176611155078

# %% [markdown]
# ## Inverse Transformation and Comparing

# %%
predictions = scaler.inverse_transform(predictions_scaled)
predictions = pd.DataFrame(data=predictions,columns=test.columns)
predictions
# Out:
#     Appliances  lights  T_outside  RH_outside  Press_mm_hg  Windspeed  \
# 0      283.878   4.223     18.769       7.342      757.370      4.644
# 1      220.810  -3.463     17.649      16.501      756.798      4.616
# 2      184.231  -8.333     16.913      24.177      756.102      4.655
# 3      162.215 -11.225     16.413      30.159      755.469      4.712
# 4      147.548 -13.777     16.125      34.426      754.891      4.769
# 5      139.060 -16.736     16.043      37.065      754.331      4.824
# 6      139.115 -20.049     16.150      38.239      753.762      4.871
# 7      149.778 -23.270     16.420      38.167      753.166      4.902
# 8      171.894 -25.924     16.815      37.089      752.534      4.911
# 9      204.968 -27.669     17.302      35.254      751.866      4.897
# 10     248.187 -28.319     17.847      32.905      751.166      4.862
# 11     299.059 -27.864     18.419      30.271      750.447      4.810
# 12     354.502 -26.416     18.987      27.573      749.727      4.747
# 13     411.063 -24.151     19.519      25.007      749.029      4.677
# mse: 3.107459808171017
# rmse: 1.7627988564130104
# ------------------------------
# T_inside
# r2_score: 0.8126844621549997
# mae: 0.16208062827586942
# mse: 0.04612876011849573
# rmse: 0.21477606970632396
# ------------------------------
# RH_inside
# r2_score: -11.527337842951727
# mae: 2.3671288463970006
# mse: 7.751290290326384
# rmse: 2.7841139147539176
# ------------------------------

# %%
index = 0
plt.figure(figsize = (20, 30))

for i in test.columns:
    index += 1
    test_eva = pd.DataFrame(test_new[i])
    test_eva["predictions"] = predictions[i].values
    plt.subplot(5, 2, index)
    sns.lineplot(x = test_eva.index, y = test_eva[i])
    sns.lineplot(x = test_eva.index, y = test_eva.predictions)
    plt.xticks(rotation=90);

# %%
compare = test_new[["Appliances"]]
compare["prediction"] = predictions["Appliances"].values
compare
# Out:
#                      Appliances  prediction
# date
# 2016-05-20 19:00:00         390     521.947
# 2016-05-20 20:00:00         420     559.663
# 2016-05-20 21:00:00         390     582.192
# 2016-05-20 22:00:00         320     596.152
# 2016-05-20 23:00:00         270     604.523
# 2016-05-21 00:00:00         290     609.391
# 2016-05-21 01:00:00         310     612.538
# 2016-05-21 02:00:00         340     615.447
# 2016-05-21 03:00:00         290     619.239
# 2016-05-21 04:00:00         340     624.595
# 2016-05-21 05:00:00         310     631.849
# 2016-05-21 06:00:00         360     640.942
# 2016-05-21 07:00:00         340     651.531
# 2016-05-21 08:00:00        1250     662.983
# 2016-05-21 09:00:00        1860     674.477
# 2016-05-21 10:00:00        2300     685.471
# 2016-05-21 11:00:00        2590     695.249
# 2016-05-21 12:00:00        1370     703.271
# 2016-05-21 13:00:00        2060     709.013
# 2016-05-21 14:00:00        1820     712.191
# 2016-05-21 15:00:00        2170     712.799
# 2016-05-21 16:00:00         600     710.838
# 2016-05-21 17:00:00         570     706.552
# 2016-05-21 18:00:00         750     700.381

# %%
compare.plot();

# %% [markdown]
# # Retrain and Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
generator = TimeseriesGenerator(scaled_full_data, scaled_full_data, length = length, batch_size = batch_size)

# %%
model = Sequential()

model.add(LSTM(100,input_shape=(length, n_features)))

model.add(Dense(n_features))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x = generator, epochs=15)
# Out:
# Epoch 1/15
# 205/205 [==============================] - 4s 12ms/step - loss: 0.0238
# Epoch 2/15
# 205/205 [==============================] - 2s 12ms/step - loss: 0.0110
# Epoch 3/15
# 205/205 [==============================] - 3s 13ms/step - loss: 0.0087
# Epoch 4/15
# 205/205 [==============================] - 3s 12ms/step - loss: 0.0074
# Epoch 5/15
# 205/205 [==============================] - 2s 12ms/step - loss: 0.0066
# Epoch 6/15
# 205/205 [==============================] - 3s 12ms/step - loss: 0.0060
# Epoch 7/15
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0057
# Epoch 8/15
# 205/205 [==============================] - 2s 12ms/step - loss: 0.0054
# Epoch 9/15
# 205/205 [==============================] - 2s 12ms/step - loss: 0.0051
# Epoch 10/15
# 205/205 [==============================] - 3s 13ms/step - loss: 0.0050
# Epoch 11/15
# 205/205 [==============================] - 3s 13ms/step - loss: 0.0047
# Epoch 12/15
# 205/205 [==============================] - 3s 12ms/step - loss: 0.0045
# Epoch 13/15
# 205/205 [==============================] - 3s 13ms/step - loss: 0.0043
# Epoch 14/15
# 205/205 [==============================] - 2s 12ms/step - loss: 0.0043
# Epoch 15/15
# 205/205 [==============================] - 2s 12ms/step - loss: 0.0042

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <AxesSubplot:>

# %%
forecast = []

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(length):
    
    # get prediction 1 time stamp ahead
    current_pred = model.predict(current_batch)
    
    # store prediction
    forecast.append(current_pred[0]) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:, 1:, :], [current_pred], axis=1)

# %%
forecast = full_scaler.inverse_transform(predictions_scaled)
forecast
# Out:
# array([[ 6.78513872e+02,  7.89144463e-01,  1.99477742e+01,
#          6.95579294e+00,  7.55800268e+02,  4.31870903e+00,
#          2.84674349e+01,  1.22383944e+01,  2.43472656e+01,
#          4.65206687e+01],
#        [ 6.70955232e+02, -6.37207737e+00,  1.81847552e+01,
#          1.14125049e+01,  7.55939290e+02,  4.57087941e+00,
#          2.76230986e+01,  1.19016505e+01,  2.41547348e+01,
#          4.67783496e+01],
#        [ 6.49405780e+02, -9.26659605e+00,  1.64289492e+01,
#          1.59677464e+01,  7.56186385e+02,  4.67618353e+00,
#          2.76808644e+01,  1.15375543e+01,  2.39686036e+01,
#          4.70456255e+01],
#        [ 6.23700274e+02, -1.02455753e+01,  1.48232935e+01,
#          2.02291794e+01,  7.56495563e+02,  4.70172750e+00,
#          2.77853175e+01,  1.11841514e+01,  2.37869329e+01,
#          4.73082002e+01],
#        [ 5.99358400e+02, -1.04805794e+01,  1.34625154e+01,
#          2.39341590e+01,  7.56846846e+02,  4.69722329e+00,
#          2.77852749e+01,  1.08334204e+01,  2.36125258e+01,
#          4.75277846e+01],
#        [ 5.81252578e+02, -1.05133688e+01,  1.24059711e+01,
#          2.68563904e+01,  7.57226205e+02,  4.69138814e+00,
#          2.76907187e+01,  1.04803802e+01,  2.34487476e+01,
#          4.76754189e+01],
#        [ 5.73336701e+02, -1.05152547e+01,  1.16864935e+01,
#          2.88198693e+01,  7.57621383e+02,  4.70174699e+00,
#          2.75387705e+01,  1.01230242e+01,  2.33002710e+01,
#          4.77306952e+01],
#        [ 5.78048652e+02, -1.04638389e+01,  1.13148029e+01,
#          2.96989079e+01,  7.58019198e+02,  4.73954687e+00,
#          2.73700330e+01,  9.76172571e+00,  2.31719956e+01,
#          4.76810115e+01],
#        [ 5.96438360e+02, -1.02560439e+01,  1.12798702e+01,
#          2.94228203e+01,  7.58411722e+02,  4.81271006e+00,
#          2.72142318e+01,  9.39554942e+00,  2.30686256e+01,
#          4.75185351e+01],
#        [ 6.28025067e+02, -9.77673564e+00,  1.15481988e+01,
#          2.79863512e+01,  7.58792935e+02,  4.92670242e+00,
#          2.70926466e+01,  9.02114986e+00,  2.29934911e+01,
#          4.72409589e+01],
#        [ 6.71228409e+02, -8.93304015e+00,  1.20669853e+01,
#          2.54597030e+01,  7.59158888e+02,  5.08447115e+00,
#          2.70147285e+01,  8.63228410e+00,  2.29481670e+01,
#          4.68502586e+01],
#        [ 7.23542961e+02, -7.67121116e+00,  1.27622322e+01,
#          2.20067274e+01,  7.59507350e+02,  5.28550936e+00,
#          2.69832731e+01,  8.21992584e+00,  2.29318713e+01,
#          4.63549438e+01],
#        [ 7.81702571e+02, -5.99141208e+00,  1.35461672e+01,
#          1.78895307e+01,  7.59833504e+02,  5.52417687e+00,
#          2.69918179e+01,  7.77673643e+00,  2.29405373e+01,
#          4.57713493e+01],
#        [ 8.42021207e+02, -3.95082483e+00,  1.43224585e+01,
#          1.34589509e+01,  7.60133768e+02,  5.78879961e+00,
#          2.70305861e+01,  7.29948691e+00,  2.29672053e+01,
#          4.51243284e+01],
#        [ 9.00902341e+02, -1.64648468e+00,  1.49985414e+01,
#          9.11240651e+00,  7.60408682e+02,  6.06224782e+00,
#          2.70892662e+01,  6.79131945e+00,  2.30034687e+01,
#          4.44434011e+01],
#        [ 9.54091756e+02,  7.70922243e-01,  1.54875799e+01,
#          5.26397156e+00,  7.60658483e+02,  6.32268203e+00,
#          2.71577174e+01,  6.26390649e+00,  2.30384057e+01,
#          4.37678930e+01],
#        [ 9.98392268e+02,  3.16759445e+00,  1.57288428e+01,
#          2.25918680e+00,  7.60894968e+02,  6.54777093e+00,
#          2.72341109e+01,  5.73249781e+00,  2.30639113e+01,
#          4.31286728e+01],
#        [ 1.02975672e+03,  5.39493954e+00,  1.56777476e+01,
#          3.69464063e-01,  7.61124151e+02,  6.71668995e+00,
#          2.73181426e+01,  5.21643217e+00,  2.30710341e+01,
#          4.25613822e+01],
#        [ 1.04534563e+03,  7.35274324e+00,  1.53270283e+01,
#         -2.67693504e-01,  7.61356559e+02,  6.81384421e+00,
#          2.74165711e+01,  4.73291255e+00,  2.30550052e+01,
#          4.20865484e+01],
#        [ 1.04162258e+03,  8.91794985e+00,  1.46820542e+01,
#          3.91812363e-01,  7.61593678e+02,  6.82935137e+00,
#          2.75352139e+01,  4.29757469e+00,  2.30109760e+01,
#          4.17281412e+01],
#        [ 1.01837385e+03,  1.00380090e+01,  1.37946088e+01,
#          2.24047086e+00,  7.61840862e+02,  6.76273604e+00,
#          2.76878633e+01,  3.91824102e+00,  2.29406633e+01,
#          4.14835184e+01],
#        [ 9.75766129e+02,  1.06358280e+01,  1.27159499e+01,
#          5.10809053e+00,  7.62095567e+02,  6.62109271e+00,
#          2.78831088e+01,  3.59697611e+00,  2.28447691e+01,
#          4.13536664e+01],
#        [ 9.15919124e+02,  1.06378790e+01,  1.15063799e+01,
#          8.78081915e+00,  7.62356639e+02,  6.41634210e+00,
#          2.81252197e+01,  3.32995519e+00,  2.27256197e+01,
#          4.13297989e+01],
#        [ 8.43161936e+02,  1.00087257e+01,  1.02335984e+01,
#          1.30174590e+01,  7.62622417e+02,  6.16472809e+00,
#          2.84129835e+01,  3.10934743e+00,  2.25867570e+01,
#          4.13933858e+01]])

# %%
df
# Out:
#                      Appliances  lights  T_outside  RH_outside  Press_mm_hg  \
# date
# 2016-01-11 17:00:00         330     210      6.590      84.260      733.750
# 2016-01-11 18:00:00        1060     310      6.180      87.200      734.270
# 2016-01-11 19:00:00        1040     150      5.860      88.130      734.790
# 2016-01-11 20:00:00         750     210      5.470      86.930      735.280
# 2016-01-11 21:00:00         620     140      5.580      86.130      735.570
# ...                         ...     ...        ...         ...          ...
# 2016-05-27 14:00:00         610      10     25.570       1.000      755.800
# 2016-05-27 15:00:00         460       0     26.280       1.000      755.670
# 2016-05-27 16:00:00         810       0     26.140       1.000      755.380
# 2016-05-27 17:00:00        1080      20     24.440       1.000      755.200
# 2016-05-27 18:00:00         430      10     21.030       1.000      755.200
#
#                      Windspeed  Visibility  Tdewpoint  T_inside  RH_inside
# date
# 2016-01-11 17:00:00      6.170      53.420      5.050    18.420     46.550
# 2016-01-11 18:00:00      5.420      40.000      4.660    18.410     46.520
# 2016-01-11 19:00:00      6.000      40.000      4.390    18.690     48.670
# 2016-01-11 20:00:00      6.000      40.000      4.020    18.940     50.360
# 2016-01-11 21:00:00      6.000      40.000      3.820    19.250     48.980
# ...                        ...         ...        ...       ...        ...
# 2016-05-27 14:00:00      2.000      21.580     13.480    24.850     45.890
# 2016-05-27 15:00:00      2.000      21.830     13.260    24.840     45.420
# 2016-05-27 16:00:00      2.420      22.580     13.280    24.890     45.990
# 2016-05-27 17:00:00      3.420      24.080     13.320    24.850     46.230
# 2016-05-27 18:00:00      4.000      27.000     13.200    24.740     46.190
#
# [3290 rows x 10 columns]

# %%
forecast_index = pd.date_range(start = '2016-05-27 19:00:00', periods = length, freq = 'H')
forecast_index
# Out:
# DatetimeIndex(['2016-05-27 19:00:00', '2016-05-27 20:00:00',
#                '2016-05-27 21:00:00', '2016-05-27 22:00:00',
#                '2016-05-27 23:00:00', '2016-05-28 00:00:00',
#                '2016-05-28 01:00:00', '2016-05-28 02:00:00',
#                '2016-05-28 03:00:00', '2016-05-28 04:00:00',
#                '2016-05-28 05:00:00', '2016-05-28 06:00:00',
#                '2016-05-28 07:00:00', '2016-05-28 08:00:00',
#                '2016-05-28 09:00:00', '2016-05-28 10:00:00',
#                '2016-05-28 11:00:00', '2016-05-28 12:00:00',
#                '2016-05-28 13:00:00', '2016-05-28 14:00:00',
#                '2016-05-28 15:00:00', '2016-05-28 16:00:00',
#                '2016-05-28 17:00:00', '2016-05-28 18:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
forecast_df = pd.DataFrame(data = forecast[:,:1], index = forecast_index, columns = ['Forecast'])
forecast_df
# Out:
#                      Forecast
# 2016-05-27 19:00:00   678.514
# 2016-05-27 20:00:00   670.955
# 2016-05-27 21:00:00   649.406
# 2016-05-27 22:00:00   623.700
# 2016-05-27 23:00:00   599.358
# 2016-05-28 00:00:00   581.253
# 2016-05-28 01:00:00   573.337
# 2016-05-28 02:00:00   578.049
# 2016-05-28 03:00:00   596.438
# 2016-05-28 04:00:00   628.025
# 2016-05-28 05:00:00   671.228
# 2016-05-28 06:00:00   723.543
# 2016-05-28 07:00:00   781.703
# 2016-05-28 08:00:00   842.021
# 2016-05-28 09:00:00   900.902
# 2016-05-28 10:00:00   954.092
# 2016-05-28 11:00:00   998.392
# 2016-05-28 12:00:00  1029.757
# 2016-05-28 13:00:00  1045.346
# 2016-05-28 14:00:00  1041.623
# 2016-05-28 15:00:00  1018.374
# 2016-05-28 16:00:00   975.766
# 2016-05-28 17:00:00   915.919
# 2016-05-28 18:00:00   843.162

# %%
ax = df["Appliances"].plot()
forecast_df.plot(ax = ax, figsize = (16, 8));

# %%
ax = df["Appliances"].plot()
forecast_df.plot(ax = ax, figsize = (16, 8))
plt.xlim("2016-05-25 18:00:00", "2016-05-28 18:00:00")
# Out:
# (406722.0, 406794.0)

# %% [markdown]
# <p style="text-align: center"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
